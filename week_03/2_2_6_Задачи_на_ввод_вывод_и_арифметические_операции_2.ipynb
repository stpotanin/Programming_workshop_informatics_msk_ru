# %%
import itertools
from sympy import symbols, Eq, solve
from sympy.parsing.sympy_parser import parse_expr

operations = ['+', '-', '*', '//', '%']
# Значения переменных
values = {x: 2, y: 3}

for op in operations:
    expr_str = f'x {op} y'
    expr = parse_expr(expr_str)
    # Подставляем значения
    expr_val = expr.subs(values)
    print(f"{expr} = {expr_val}")
# Out:
# x + y = 5
# x - y = -1
# x*y = 6
# floor(x/y) = 0
# Mod(x, y) = 2
