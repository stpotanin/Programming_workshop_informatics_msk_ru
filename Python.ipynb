# %%
# @title https://stepik.org/lesson/427799/step/8
# _, x = input(), input().split()
x = [1, 2, 3, 4, 5]

# print(*(xx for xx in [(x2, x1) for x1, x2 in zip(x[:-1:2], x[1::2])]))

print(*(xx for pair in [(x2, x1) for x1, x2 in zip(x[:-1:2], x[1::2])] for xx in pair), x[-1] if len(x) % 2 == 1 else '')


# 6
# 4 5 3 4 2 3
# 5 4 4 3 3 2 out
# Out:
# 2 1 4 3 5

# %%
x = [1, ]
print(*[x.pop(),] + x)
# Out:
# 1

# %%
# x = [1, 2, 3, 4, 5]
x = [int(x) for x in input().split()]
x[x.index(max(x))], x[x.index(min(x))] = x[x.index(min(x))], x[x.index(max(x))]
print(*x)
# Out:
# 3 4 5 2 1
# 3 4 5 2 1

# %%
# @title https://stepik.org/lesson/464324/step/3
x = [int(xx) for xx in input().split()]
k, C = [int(xx) for xx in input().split()]

x.append(0)
x[k:] = [C, *[xx for xx in x[k:len(x)-1]]]
print(*x)
x[k:-1]
# 7 6 5 4 3 2 1
# 2 0
# out 7 6 0 5 4 3 2 1
# Out:
# 7 6 5 4 3 2 1
# 2 0
# 7 6 0 5 4 3 2 1
# [0, 5, 4, 3, 2]

# %%
# @title https://stepik.org/lesson/464324/step/7
(lambda s: print(max(s, key=s.count)))(input().split())
# Out:
# 1 2 3 2 2 2 3 3 3
# 2

# %%
# @title https://stepik.org/lesson/464324/step/7
# x = ['4', '0', '5', '0', '3', '0', '0', '5']
(lambda x: print(*[xx for xx in x if xx != '0'], *[xx for xx in x if xx == '0']))(input().split())
# 4 0 5 0 3 0 0 5
# 4 5 3 5 0 0 0 0
# Out:
# 4 0 5 0 3 0 0 5
# 4 5 3 5 0 0 0 0

# %%
import numpy as np

n, m = [int(x) for x in input().split()]

x = np.zeros((n, m))
rows, cols = np.indices((n, m))
res = rows * cols

for row in res:
    print(*row)
# Out:
# 3 3
# 0 0 0
# 0 1 2
# 0 2 4

# %%
[int(x) for x in input().split()]

# %%
import numpy as np

n, m = 4, 3
x = np.zeros((n, m))
rows, cols = np.indices((n, m))
rows, cols
# Out:
# (array([[0, 0, 0],
#         [1, 1, 1],
#         [2, 2, 2],
#         [3, 3, 3]]),
#  array([[0, 1, 2],
#         [0, 1, 2],
#         [0, 1, 2],
#         [0, 1, 2]]))

# %%
# @title https://stepik.org/lesson/427802/step/3 Количество дней от начала эры

import datetime

d = datetime.datetime.strptime(input(), '%d%m%Y')

print(d.date().toordinal())

# 01010001 1
# 29020004 1155
# 14042023 738624
# 18060636 232098
# Out:
# 01010001
# 1
